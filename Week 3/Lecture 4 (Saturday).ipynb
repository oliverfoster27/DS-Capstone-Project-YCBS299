# %% [markdown]
# # GCP Demos

# %% [markdown]
# ### Capstone Project GCP Location: https://console.cloud.google.com/home/dashboard?project=project2-2019-259821

# %% [markdown]
# ### Geo info: http://donnees.ville.montreal.qc.ca/dataset/geobase
# https://robertorocha.info/how-i-made-the-montreal-street-history-map/

# %%
import requests
import json

# %%
req = requests.get(r"http://donnees.ville.montreal.qc.ca/dataset/984f7a68-ab34-4092-9204-4bdfcca767c5/resource/9d3d60d8-4e7f-493e-8d6a-dcd040319d8d/download/geobase.json")

# %%
data = req.text

# %%
data_json = json.loads(data)

# %%
with open(r"C:\Users\olive\Documents\GitHub\DS-Capstone-Project-YCBS299\Week 3\geojson_dump.json", 'w') as f:    
    f.write(json.dumps(data_json))

# %%
data_json
# Out:
# {'name': 'geobase_mtl',
#  'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-73.74081689158372, 45.51897292308536],
#      [-73.7419541040326, 45.519703332189074]]},
#    'properties': {'ID_TRC': 1010001,
#     'DEB_GCH': 12320,
#     'FIN_GCH': 12340,
#     'ARR_GCH': 'Ahuntsic-Cartierville',
#     'SENS_CIR': 0,
#     'CLASSE': 0,
#     'LIE_VOIE': None,
#     'TYP_VOIE': 'avenue',
#     'DIR_VOIE': None,
#     'NOM_VOIE': 'Adhémar-Mailhiot',
#     'DEB_DRT': 12323,
#     'FIN_DRT': 12335,
#     'ARR_DRT': 'Ahuntsic-Cartierville',
#     'LIM_GCH': 'Montréal',
#     'LIM_DRT': 'Montréal'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-73.70623530423325, 45.527646493721306],
#      [-73.70629430924254, 45.52759778866121],
#      [-73.7066906006261, 45.52727777851528],
#      [-73.70671238591936, 45.52725785084725],
#      [-73.7067274208916, 45.527240095005574],
# ...
